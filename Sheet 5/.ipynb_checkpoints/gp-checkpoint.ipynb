# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import sobol
import GPy
import scipy

# %% [markdown]
# # 1 GP Optimization of a Toy Problem

# %% [markdown]
# Implementation and visualization of $f(x,y)$.

# %%
def f(x,y):
    return np.square(x) - x + np.square(y) + y - np.cos((2*x -1 )*np.pi) - np.cos((2*y + 1)*np.pi) + 2.5

# %%
def visualization():
    X = np.arange(-6,6,0.05)
    X, Y = np.meshgrid(X, X)
    Z = f(X, Y)
    
    fig = plt.figure(figsize=(10,10))
    ax = fig.gca(projection='3d')
    
    surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm, linewidth=0, antialiased=False)
       
    plt.show()

# %%
visualization()

# %% [markdown]
# Creating initial 30 training points using sobol and computing the corresponding Z-values.

# %%
number_of_samples = 30
X = np.zeros([number_of_samples,2]) #training vector to be filled
parameterUpperLimits = np.array([6,6])
parameterLowerLimits = np.array([-6, -6])
for i in range(number_of_samples):
    X[i,:] = sobol.i4_sobol(2,i)[0] * (parameterUpperLimits - parameterLowerLimits) + parameterLowerLimits
    
Z = f(X[:,0],X[:,1])[:,None]

# %% [markdown]
# Create and train a first GP Regression model.

# %%
kernel = GPy.kern.RBF(2) + GPy.kern.White(2)
m = GPy.models.GPRegression(X,Z,kernel)
m.optimize()

# %%
fig = m.plot()
display(GPy.plotting.show(fig, filename='basic_gp_regression_notebook_2d'))
display(m)
# Out:
#  C:\Users\Alex\Anaconda3\envs\ml\lib\site-packages\matplotlib\figure.py:1743: UserWarning:This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
# <style type="text/css">
# .pd{
#     font-family: "Courier New", Courier, monospace !important;
#     width: 100%;
#     padding: 3px;
# }
# </style>
#
# <p class=pd>
# <b>Model</b>: GP regression<br>
# <b>Objective</b>: 78.08645392384075<br>
# <b>Number of Parameters</b>: 4<br>
# <b>Number of Optimization Parameters</b>: 4<br>
# <b>Updates</b>: True<br>
# </p>
# <style type="text/css">
# .tg  {font-family:"Courier New", Courier, monospace !important;padding:2px 3px;word-break:normal;border-collapse:collapse;border-spacing:0;border-color:#DCDCDC;margin:0px auto;width:100%;}
# .tg td{font-family:"Courier New", Courier, monospace !important;font-weight:bold;color:#444;background-color:#F7FDFA;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg th{font-family:"Courier New", Courier, monospace !important;font-weight:normal;color:#fff;background-color:#26ADE4;border-style:solid;border-width:1px;overflow:hidden;word-break:normal;border-color:#DCDCDC;}
# .tg .tg-left{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:left;}
# .tg .tg-center{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:center;}
# .tg .tg-right{font-family:"Courier New", Courier, monospace !important;font-weight:normal;text-align:right;}
# </style>
# <table class="tg"><tr><th><b>  GP_regression.         </b></th><th><b>         value</b></th><th><b>constraints</b></th><th><b>priors</b></th></tr>
# <tr><td class=tg-left>  sum.rbf.variance       </td><td class=tg-right> 168100.869457</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.rbf.lengthscale    </td><td class=tg-right> 23.7736000429</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  sum.white.variance     </td><td class=tg-right>0.564921543797</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# <tr><td class=tg-left>  Gaussian_noise.variance</td><td class=tg-right>0.564921543797</td><td class=tg-center>    +ve    </td><td class=tg-center>      </td></tr>
# </table>

# %%
m.predict(np.array([[0.5,-0.5]]), full_cov=False)
# Out:
# (array([[ 2.04353159]]), array([[ 1.28391124]]))

# %%
def u(model, q):
    # q has to be a numpy array with shape (1,2)
    E_q, Var_q = model.predict(q)
    E_best = 1#??? TODO
    gamma_q = (E_best - E_q) / np.sqrt(Var_q)
    u = np.sqrt(Var_q) * (gamma_q * scipy.stats.norm.cdf(gamma_q) + scipy.stats.norm.pdf(gamma_q))
    
    return u
